# %%
import matplotlib.pyplot as plt
import decimal
import random
import pandas as pd
import seaborn as sns
import matplotlib.ticker as ticker
import numpy as np
import math
import numpy
from scipy import signal
import seaborn as sns
from matplotlib.pyplot import figure
from math import sqrt

# %%
t = np.linspace(0, 1000, 100000, endpoint=False)
A = 1
sinusoid = A*(np.sin(t))*(np.sin(sqrt(2)*t))
noise = np.random.rand(100000)-0.5
signal=sinusoid+0*noise
signal1=sinusoid+1*noise

# %%
figure(figsize=(8, 6), dpi=80)
plt.plot(t,sinusoid)
plt.title('График чистого сигнала')
plt.ylabel('Амплитуда')
plt.xlabel('t, cекунд')
plt.grid()
plt.xlim(0, 1000)

figure(figsize=(8, 6), dpi=80)
plt.plot(t,sinusoid)
plt.title('График чистого сигнала в приближение')
plt.ylabel('Амплитуда')
plt.xlabel('t, cекунд')
plt.grid()
plt.xlim(0, 100)
# Out:
# (0.0, 100.0)

# %%
figure(figsize=(8, 6), dpi=80)
plt.plot(t,noise)
plt.title('График шума')
plt.ylabel('Амплитуда')
plt.xlabel('t, cекунд')
plt.grid()
plt.xlim(0, 1000)

figure(figsize=(8, 6), dpi=80)
plt.plot(t,noise)
plt.title('График шума в приближение')
plt.ylabel('Амплитуда')
plt.xlabel('t, cекунд')
plt.grid()
plt.xlim(0, 1)
# Out:
# (0.0, 1.0)

# %%
figure(figsize=(8, 6), dpi=80)
plt.plot(t,noise)
plt.title('График шума')
plt.ylabel('Амплитуда')
plt.xlabel('t, cекунд')
plt.grid()
plt.xlim(0, 1000)

figure(figsize=(8, 6), dpi=80)
plt.plot(t,noise)
plt.title('График сигнала')
plt.ylabel('Амплитуда')
plt.xlabel('t, cекунд')
plt.grid()
plt.xlim(0, 1)
# Out:
# (0.0, 1.0)

# %%
figure(figsize=(8, 6), dpi=80)
plt.plot(t,signal)
plt.title('График сигнала c шумом при λ=0 ')
plt.ylabel('Амплитуда')
plt.xlabel('t, cекунд')
plt.grid()
plt.xlim(0, 100)
# Out:
# (0.0, 100.0)

# %%
figure(figsize=(8, 6), dpi=80)
plt.plot(t,signal1)
plt.title('График сигнала c шумом при λ=1 ')
plt.ylabel('Амплитуда')
plt.xlabel('t, cекунд')
plt.grid()
plt.xlim(0, 100)
# Out:
# (0.0, 100.0)

# %%
N = 10000
T = 1.0 / 300.0
x = np.linspace(0.0, N*T, N, endpoint=False)

t = np.linspace(0, 1000, 10000, endpoint=False)
A = 1
sinusoid = A*(np.sin(t))*(np.sin(sqrt(2)*t))

y = sinusoid
yf = fft(y)
xf = fftfreq(N, T)
xf = fftshift(xf)
yplot = fftshift(yf)

figure(figsize=(10, 7), dpi=80)
plt.plot(xf, 1.0/N * np.abs(yplot))
plt.grid()
plt.title('Спектор чистого сигнала')
plt.ylabel('Мощность')
plt.xlabel('Частота, ГЦ')
#plt.xlim(-2000, 2000)
plt.show()

# %%
N = 100000
T = 1.0 / 600.0
x = np.linspace(0.0, N*T, N, endpoint=False)

t = np.linspace(0, 1000, 100000, endpoint=False)
noise = np.random.rand(100000)-0.5

y = noise
yf = fft(y)
xf = fftfreq(N, T)
xf = fftshift(xf)
yplot = fftshift(yf)

figure(figsize=(10, 7), dpi=80)
plt.plot(xf, 1.0/N * np.abs(yplot))
plt.grid()
plt.title('Спектор шума')
plt.ylabel('Мощность')
plt.xlabel('Частота, ГЦ')
#plt.xlim(-2000, 2000)
plt.show()

# %%
N = 10000
T = 1.0 / 600.0
x = np.linspace(0.0, N*T, N, endpoint=False)

t = np.linspace(0, 1000, 10000, endpoint=False)
A = 1
sinusoid = A*(np.sin(t))*(np.sin(sqrt(2)*t))
noise = np.random.rand(10000)-0.5
signal1=sinusoid+1*noise

y = signal1
yf = fft(y)
xf = fftfreq(N, T)
xf = fftshift(xf)
yplot = fftshift(yf)

figure(figsize=(10, 7), dpi=80)
plt.plot(xf, 1.0/N * np.abs(yplot))
plt.grid()
plt.title('Спектор сигнала с шумом')
plt.ylabel('Мощность')
plt.xlabel('Частота, ГЦ')
#plt.xlim(-2000, 2000)
plt.show()
