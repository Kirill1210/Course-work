# %%
import matplotlib.pyplot as plt
import decimal
import random
import pandas as pd
import seaborn as sns
import matplotlib.ticker as ticker
import numpy as np
import math
import numpy
from scipy import signal
import seaborn as sns
from matplotlib.pyplot import figure
from math import sqrt

# %%
t = np.linspace(0, 1000, 1000, endpoint=False)
A = 1
sinusoid = A*(np.sin(t))*(np.sin(sqrt(2)*t))
noise = np.random.rand(1000)-0.5

# %%
figure(figsize=(8, 6), dpi=80)
plt.plot(t,sinusoid)
plt.title('График сигнала')
plt.ylabel('Частота')
plt.xlabel('t, cекунд')
plt.grid()
plt.xlim(0, 1000)
# Out:
# (0.0, 1000.0)

# %%
figure(figsize=(8, 6), dpi=80)
plt.plot(t,noise)
plt.title('График шума')
plt.ylabel('Частота')
plt.xlabel('t, cекунд')
plt.grid()
plt.xlim(0, 1000)
# Out:
# (0.0, 1000.0)

# %%
λ=0
signal=sinusoid+λ*noise

# %%
figure(figsize=(8, 6), dpi=80)
plt.plot(t,signal)
plt.title('График сигнала c шумом при λ=0 ')
plt.ylabel('Частота')
plt.xlabel('t, cекунд')
plt.grid()
plt.xlim(0, 1000)
# Out:
# (0.0, 1000.0)

# %%
λ=1
signal=sinusoid+λ*noise

# %%
figure(figsize=(8, 6), dpi=80)
plt.plot(t,signal)
plt.title('График сигнала c шумом при λ=1')
plt.ylabel('Частота')
plt.xlabel('t, cекунд')
plt.grid()
plt.xlim(0, 1000)
# Out:
# (0.0, 1000.0)

# %%
t = np.linspace(0, 1000, 1000, endpoint=False)
A = 1
sinusoid = A*(np.sin(t))*(np.sin(sqrt(2)*t))
noise = np.random.rand(1000)-0.5
signal= sinusoid + (1*noise)
signal1= sinusoid + (0*noise)

# %%
plt.specgram(noise, NFFT=256, pad_to=256, mode='magnitude', Fs=2, cmap=cmap)
plt.title('Спектограмма сигнала шума')
plt.xlabel("Время, c")
plt.ylabel("'Частота, Гц'")
plt.colorbar()
plt.show()

# %%
plt.specgram(signal1, NFFT=256, pad_to=256, mode='magnitude', Fs=2, cmap=cmap)
plt.title('Спектограмма сигнала с шумом при λ=0')
plt.xlabel("Время, c")
plt.ylabel("'Частота, Гц'")
plt.colorbar()
plt.show()

# %%
plt.specgram(signal, NFFT=256, pad_to=256, mode='magnitude', Fs=2, cmap=cmap)
plt.title('Спектограмма сигнала с шумом при λ=1')
plt.xlabel("Время, c")
plt.ylabel("'Частота, Гц'")
plt.colorbar()
plt.show()
